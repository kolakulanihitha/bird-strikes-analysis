# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\nihit\Downloads\Bird Strikes data.csv")
df.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight       FlightDate  \
# 0                             859         Engine Shut Down  11/23/2000 0:00
# 1                             424                      NaN   7/25/2001 0:00
# ...

# %%
df.shape
# Out:
# (25558, 26)

# %%
df.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count   25558.000000                    25558.000000              25558.000000
# mean   253916.085609                        2.691525                  0.001056
# std     38510.453382                       12.793975                  0.050420
# min      1195.000000                        1.000000                  0.000000
# 25%    225783.750000                        1.000000                  0.000000
# 50%    248749.000000                        1.000000                  0.000000
# 75%    269168.750000                        1.000000                  0.000000
# max    321909.000000                      942.000000                  6.000000

# %%
columns = list(df)
columns
# Out:
# ['Record ID',
#  'Aircraft: Type',
#  'Airport: Name',
#  'Altitude bin',
#  'Aircraft: Make/Model',
#  'Wildlife: Number struck',
#  'Wildlife: Number Struck Actual',
#  'Effect: Impact to flight',
#  'FlightDate',
#  'Effect: Indicated Damage',
#  'Aircraft: Number of engines?',
#  'Aircraft: Airline/Operator',
#  'Origin State',
#  'When: Phase of flight',
#  'Conditions: Precipitation',
#  'Remains of wildlife collected?',
#  'Remains of wildlife sent to Smithsonian',
#  'Remarks',
#  'Wildlife: Size',
#  'Conditions: Sky',
#  'Wildlife: Species',
#  'Pilot warned of birds or wildlife?',
#  'Cost: Total $',
#  'Feet above ground',
#  'Number of people injured',
#  'Is Aircraft Large?']

# %%
df.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Remarks                                     4771
# Wildlife: Size                               129
# ...

# %%
(df[columns[0:24]]==0).sum()
# Out:
# Record ID                                      0
# Aircraft: Type                                 0
# Airport: Name                                  0
# Altitude bin                                   0
# Aircraft: Make/Model                           0
# Wildlife: Number struck                        0
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                       0
# FlightDate                                     0
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                   0
# Aircraft: Airline/Operator                     0
# Origin State                                   0
# When: Phase of flight                          0
# Conditions: Precipitation                      0
# Remains of wildlife collected?             18732
# Remains of wildlife sent to Smithsonian    23601
# Remarks                                        0
# Wildlife: Size                                 0
# ...

# %%
df[columns[0:24]]=df[columns[0:24]].replace(0,np.nan)

# %%
df.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Remarks                                     4771
# Wildlife: Size                               129
# ...

# %%
df.shape
# Out:
# (25558, 26)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (180, 26)

# %%
df.index
# Out:
# Index([  210,   222,   260,   273,   339,   448,   524,   674,   774,   803,
#        ...
#        22475, 23304, 23766, 23773, 24087, 24550, 24784, 25078, 25372, 25417],
#       dtype='int64', length=180)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, 210 to 25417
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                180 non-null    int64
#  1   Aircraft: Type                           180 non-null    object
#  2   Airport: Name                            180 non-null    object
#  3   Altitude bin                             180 non-null    object
#  4   Aircraft: Make/Model                     180 non-null    object
#  5   Wildlife: Number struck                  180 non-null    object
#  6   Wildlife: Number Struck Actual           180 non-null    int64
#  7   Effect: Impact to flight                 180 non-null    object
#  8   FlightDate                               180 non-null    object
#  9   Effect: Indicated Damage                 180 non-null    object
# ...

# %%
print(df.dtypes)
# Out:
# Record ID                                   int64
# Aircraft: Type                             object
# Airport: Name                              object
# Altitude bin                               object
# Aircraft: Make/Model                       object
# Wildlife: Number struck                    object
# Wildlife: Number Struck Actual              int64
# Effect: Impact to flight                   object
# FlightDate                                 object
# Effect: Indicated Damage                   object
# Aircraft: Number of engines?               object
# Aircraft: Airline/Operator                 object
# Origin State                               object
# When: Phase of flight                      object
# Conditions: Precipitation                  object
# Remains of wildlife collected?               bool
# Remains of wildlife sent to Smithsonian      bool
# Remarks                                    object
# Wildlife: Size                             object
# ...

# %%
df['Cost: Total $'] = pd.to_numeric(df['Cost: Total $'].str.replace(',', ''), errors='coerce')
df['Feet above ground'] = pd.to_numeric(df['Feet above ground'], errors='coerce')

# %%
mean_all = df.mean(numeric_only=True)

print("Mean values for all numerical columns:")
print(mean_all)
# Out:
# Mean values for all numerical columns:
# Record ID                                  245206.261111
# Wildlife: Number Struck Actual                  7.994444
# Remains of wildlife collected?                  0.466667
# Remains of wildlife sent to Smithsonian         0.205556
# Cost: Total $                               62127.294444
# Feet above ground                              79.475000
# Number of people injured                        0.000000
# dtype: float64

# %%
median_all = df.median(numeric_only=True)

print("Median values for all numerical columns:")
print(median_all)
# Out:
# Median values for all numerical columns:
# Record ID                                  237834.5
# Wildlife: Number Struck Actual                  1.0
# Remains of wildlife collected?                  0.0
# Remains of wildlife sent to Smithsonian         0.0
# Cost: Total $                                   0.0
# Feet above ground                               0.0
# Number of people injured                        0.0
# dtype: float64

# %%
# Calculate the mode for the 'Aircraft: Make/Model' column
mode_value = df['Aircraft: Make/Model'].mode()

print(f"The mode of the 'Aircraft: Make/Model' column is: {mode_value.iloc[0]}")
# Out:
# The mode of the 'Aircraft: Make/Model' column is: B-737-300

# %%
# Calculate the mode for the 'Wildlife: Species' column
mode_value = df['Wildlife: Species'].mode()

print(f"The mode of the 'Wildlife: Species' column is: {mode_value.iloc[0]}")
# Out:
# The mode of the 'Wildlife: Species' column is: Unknown bird - medium

# %%
# Calculate the mode for the 'Altitude bin' column
mode_value = df['Altitude bin'].mode()

print(f"The mode of the 'Altitude bin' column is: {mode_value.iloc[0]}")
# Out:
# The mode of the 'Altitude bin' column is: < 1000 ft

# %%
# Calculate the mode for the 'Pilot warned of birds or wildlife?' column
mode_value = df['Pilot warned of birds or wildlife?'].mode()

print(f"The mode of the 'Pilot warned of birds or wildlife?' column is: {mode_value.iloc[0]}")
# Out:
# The mode of the 'Pilot warned of birds or wildlife?' column is: N

# %%
import matplotlib.pyplot as plt

value_counts = df['Pilot warned of birds or wildlife?'].value_counts()

# Plot the bar chart
plt.figure(figsize=(6, 4))
value_counts.plot(kind='bar', color='red')
plt.title('Frequency of Pilot Warnings About Birds or Wildlife')
plt.xlabel('Warning Status')
plt.ylabel('Count')
plt.tight_layout()
plt.legend()
plt.show()

# %%
value_counts = df['Effect: Impact to flight'].value_counts()

# Plot the bar chart
plt.figure(figsize=(12, 8))
value_counts.plot(kind='bar', color='lightcoral')
plt.title('Frequency of Impact Effects on Flight')
plt.xlabel('Impact Effect')
plt.ylabel('Count')
plt.tight_layout()
plt.legend()
plt.show()

# %%
cost_by_effect = df.groupby('Effect: Impact to flight')['Cost: Total $'].sum()
plt.figure(figsize=(12, 8))
cost_by_effect.plot(kind='bar', color='dodgerblue')
plt.title('Total Cost by Impact Effect on Flight')
plt.xlabel('Impact Effect')
plt.ylabel('Total Cost ($)')
plt.tight_layout()
plt.legend()
plt.show()

# %%
#histogram for the 'Cost: Total $' column
plt.figure(figsize=(10, 6))
plt.hist(df['Cost: Total $'].dropna(), bins=30, color='salmon', edgecolor='black')
plt.title('Histogram of Distribution of Total Costs')
plt.xlabel('Total Cost ($)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#  histogram for the 'Altitude bin' column
plt.figure(figsize=(12, 8))
df['Altitude bin'].value_counts().sort_index().plot(kind='bar', color='lightcoral', edgecolor='black')
plt.title('Histogram of Distribution of Altitude Bins')
plt.xlabel('Altitude Bin')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
#Distribution plot for the 'Cost: Total $' column
plt.figure(figsize=(12, 8))
sns.histplot(df['Cost: Total $'].dropna(), kde=True, color='purple', bins=30)
plt.title('Distribution of Total Costs')
plt.xlabel('Total Cost ($)')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
# Plot the distribution plot of 'Effect: Impact to flight'
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Effect: Impact to flight', palette='Pastel1', order=df['Effect: Impact to flight'].value_counts().index)
plt.title('Distribution of Impact Effects on Flight')
plt.xlabel('Impact Effect')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
skewness = df['Cost: Total $'].dropna().skew()

print(f"The skewness of the 'Cost: Total $' column is: {skewness}")
# Out:
# The skewness of the 'Cost: Total $' column is: 7.2963621052567476

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Effect: Impact to flight_encoded'] = le.fit_transform(df['Effect: Impact to flight'].astype(str))

# Calculate the skewness of the encoded 'Effect: Impact to flight' column
skewness = df['Effect: Impact to flight_encoded'].skew()

print(f"The skewness of the 'Effect: Impact to flight' column is: {skewness}")
# Out:
# The skewness of the 'Effect: Impact to flight' column is: -0.47256920858133206

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df['Altitude bin'], df['Cost: Total $'], alpha=0.5)
plt.title('Scatter Plot of Altitude Bin vs. Total Cost')
plt.xlabel('Altitude Bin')
plt.ylabel('Total Cost ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print(df[['Altitude bin', 'Cost: Total $']].head())

# Plot the box plot for 'Altitude bin' vs 'Cost: Total $'
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='Altitude bin', y='Cost: Total $', palette='Set2')
plt.title('Box Plot of Total Costs by Altitude Bin')
plt.xlabel('Altitude Bin')
plt.ylabel('Total Cost ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#     Altitude bin  Cost: Total $
# 210    > 1000 ft              0
# 222    < 1000 ft              0
# 260    > 1000 ft              0
# 273    < 1000 ft              0
# 339    < 1000 ft              0

# %%
std_dev = df['Cost: Total $'].dropna().std()

print(f"The standard deviation of the 'Cost: Total $' column is: {std_dev}")
# Out:
# The standard deviation of the 'Cost: Total $' column is: 353973.44673541636

# %%
sample_variance = df['Cost: Total $'].dropna().var()

print(f"The sample variance of the 'Cost: Total $' column is: {sample_variance}")
# Out:
# The sample variance of the 'Cost: Total $' column is: 125297200993.75066

# %%
population_variance = df['Cost: Total $'].dropna().var(ddof=0)

print(f"The population variance of the 'Cost: Total $' column is: {population_variance}")
# Out:
# The population variance of the 'Cost: Total $' column is: 124601105432.67426
